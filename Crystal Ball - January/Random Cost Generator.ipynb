# %%
import pandas as pd
import numpy as np
df = pd.read_csv('JanWeeklyDemand.csv')

# %%
items = df['ItemCode'].str.lstrip('0')
items = items.unique()
partlist=[]
for p in items:
    if p[0:2] == 'SR':
        p2 = p[2:]
    else:
        p2 = p
    partlist.append(p2)
items = pd.Series(partlist).unique()

# %%
branches = pd.read_csv('JanBranches.csv')

# %%
branches = branches['Branch'].values.tolist()

# %%
tuplist = []
for j in branches:
    for k in branches:
        for i in items: 
            tuplist.append((j,k,i))

# %%
data = pd.DataFrame(tuplist,columns = ['From','To','Item'])

# %%
data['Cost'] = np.random.randint(1,101,size = len(data))
data = data.groupby(by = ['From','To','Item']).mean()

# %%
data
# Out:
#                                         Cost
# From          To            Item
# Atlanta F&S   Atlanta F&S   0200600       41
#                             0240600       43
#                             0241000       40
#                             0241200       51
#                             0241250       37
#                             0241600       89
#                             0241601       15
#                             0241608       36
#                             0241616       53
#                             0241690       43
#                             0241800       90
#                             0241812        8
#                             0242000       15
#                             0242001       52
#                             0242008       71
#                             0242010       12
#                             0242012       34
#                             0242070       30
#                             0242400        5
# ...

# %%
data.to_csv('RandomCosts.csv')

# %%
# Example of Selection: data['Cost']['Atlanta F&S','Atlanta F&S','002488US']
